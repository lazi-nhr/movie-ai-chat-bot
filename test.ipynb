# %%
from extraction import Extraction
from embeddings import Embeddings
from agent import Agent
from factual import Factual
from multimedia import Multimedia

# %%
extraction = Extraction() # not necessary here, only if you wnat to test specific functions of this class
embeddings = Embeddings() # not necessary here, only if you wnat to test specific functions of this class
factual = Factual() # not necessary here, only if you wnat to test specific functions of this class¨
multimedia = Multimedia()
agent = Agent()

# %%
questions = {
    "Please answer this question with a factual approach: From what country is the movie 'Aro Tolbukhin. En la mente del asesino'?":
        "The factual answer is: Mexico",

    "Please answer this question with a factual approach: Who is the screenwriter of 'Shortcut to Happiness'?":
        "The factual answer is: Pete Dexter",

    "Please answer this question with a factual approach: Who directed ‘Fargo’?":
        "The factual answer is: Ethan Coen and Joel Coen",

    "Please answer this question with a factual approach: What genre is the movie 'Bandit Queen'?":
        "The factual answer is: drama film and biographical film and crime film",

    "Please answer this question with a factual approach: When did the movie 'Miracles Still Happen' come out?":
        "The factual answer is: 1974-07-19",

    "Please answer this question with an embedding approach: Who is the director of ‘Apocalypse Now’?":
        "The answer suggested by embeddings is: John Milius (type: Q5)",

    "Please answer this question with an embedding approach: Who is the screenwriter of ‘12 Monkeys’?":
        "The answer suggested by embeddings is: Carol Florence (type: Q5)",

    "Please answer this question with an embedding approach: What is the genre of ‘Shoplifters’?":
        "The answer suggested by embeddings is: comedy film (type: Q201658)",

    "Please answer this question: Who is the director of ‘Good Will Hunting’?":
        "The factual answer is: Gus Van Sant. The answer suggested by embeddings is: Harmony Korine (type: Q5)",
}

# %%
requests = {
    "Recommend movies like Nightmare on Elm Street, Friday the 13th, and Halloween.":
    "Adequate recommendations will be horror movies from the 1970s or 1980s or sequels to the movies.",

    "Given that I like The Lion King, Pocahontas, and The Beauty and the Beast, can you recommend some movies?":
    "Adequate recommendations will be (2-D) animated movies or real-life remakes of Disney movies.",

    "Recommend movies similar to Hamlet and Othello.":
    "Adequate recommendations will be movies in the drama genre that are based on classic literature (e.g., Shakespeare, Dickens, or Jane Austen).",    
}

# %%
questions = {
    "From what country is the movie 'Aro Tolbukhin. En la mente del asesino'?":
        "Mexico",
    
    "Who is the screenwriter of 'Shortcut to Happiness'?":
        "Pete Dexter",
    
    "Who directed ‘Fargo’?":
        "Ethan Coen and Joel Coen ",
    
    "What genre is the movie 'Bandit Queen'?":
        "drama film and biographical film and crime film",
    
    "When did the movie 'Miracles Still Happen' come out?":
        "1974-07-19",
    
    "Who is the director of ‘Apocalypse Now’?":
        "I think John Milius",
    
    "Who is the screenwriter of ‘12 Monkeys’?":
        "I think Carol Florence",

    "What is the genre of ‘Shoplifters’?":
        "I think comedy film",

    "Who is the director of ‘Good Will Hunting’?":
        "Gus Van Sant.",
    
    "Who directed ‘Garden State’?":
        "Zach Braff",
    
    "What awards was the movie 'Midnight in Paris' nominated for?":
        "Academy Award for Best Writing, Original Screenplay and Academy Award for Best Picture and Academy Award for Best Director and Academy Award for Best Production Design",
    
    "Who is the director of ‘Forrest Gump’?":
        "I think Lenny Herb",
    
    "Who is the director of ‘The Longest Day’?":
        "I think Irina Demick",
    
    "Who was ‘Captain America: Civil War’ directed by?":
        "I think Amelia Morck",

    "Who is the director of ‘The Ascent’?":
        "Lurisu Shaputka",
}

# %%
requests = {
    "Recommend movies like Nightmare on Elm Street, Friday the 13th, and Halloween.":
        "Adequate recommendations will be horror movies from the 1970s or 1980s or sequels to the movies.",

    "Given that I like The Lion King, Pocahontas, and The Beauty and the Beast, can you recommend some movies?":
        "Adequate recommendations will be (2-D) animated movies or real-life remakes of Disney movies.",

    "Recommend movies similar to Hamlet and Othello.":
        "Adequate recommendations will be movies in the drama genre that are based on classic literature (e.g., Shakespeare, Dickens, or Jane Austen).",
    
    "I like Singin' in the Rain, and Moulin Rouge. What other movies would you recommend for me to watch? ":
        "Answers would include musical films from the 1950s ",

    "Recommend movies similar to La Dolce Vita and The Voice of the Moon.":
        "The adequate recommendations may include any movies from Italian director Federico Fellini or any Italian drama films.",
    
    "I really enjoyed Chicago, Memoirs of a Geisha, and Alice in Wonderland. Can you recommend me some similar movies?":
        "Adequate recommendations include any movie where Colleen Atwood was the costume designer or any movie, winner or nominated, for the Academy Award for Best Costume Design.",

    "Recommend some movies similar to Forrest Gump and The Lord of the Rings: The Fellowship of the Ring.":
        "The adequate recommendations include mostly the 15 top user-rated movies.",
    
    "What other movies in Japanese do you recommend? I liked Twin Sisters of Kyoto.":
        "Answers include  any other movies with composer Tōru Takemitsu or any other movies in Japanese.",

    "Can you recommend some biographical movies given that I like Meryl Streep?":
        "(e.g. Florence Foster Jenkins, The Iron Lady, Julie & Julia, The Post, Julia, Out of Africa, Music of the Heart, Evil Angels, Silkwood)",
}
